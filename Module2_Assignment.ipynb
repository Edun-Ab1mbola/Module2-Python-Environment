# %% [markdown]
# # Module 2 Assignment
# ## Setting Up Your Python Environment
# ### Using Conda AND venv

# %% [markdown]
# ## Part B — Conda Environment Setup

# %% [markdown]
# ![Screenshot 1](assignment%201.png)

# %% [markdown]
# ## Part B — Conda Package Installation

# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)
# Out:
# NumPy: 2.5.2
# Pandas: 3.0.5
# Matplotlib: 3.11.1
# Seaborn: 0.13.2

# %% [markdown]
# ### Conda Package Verification Screenshot

# %% [markdown]
# ![origin ass 2.png](attachment:76b37fcc-e52d-408e-9fe6-135d3447f133.png)

# %% [markdown]
# ## Part C — venv Environment Setup

# %% [markdown]
# ![assign 3.png](attachment:2901ffa3-cfc1-4eab-87a4-c356e4103606.png)

# %% [markdown]
# ## Part C — venv Package Installation

# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)
# Out:
# NumPy: 2.5.2
# Pandas: 3.0.5
# Matplotlib: 3.11.1
# Seaborn: 0.13.2

# %% [markdown]
# ### venv Package Verification Screenshot

# %% [markdown]
# ![assignment 4.png](attachment:555320f0-b504-4597-8a63-c2b11d5ec9eb.png)
